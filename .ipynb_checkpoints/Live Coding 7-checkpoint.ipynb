# %%
import pandas as pd
import seaborn as sns
import numpy as np

diamonds = sns.load_dataset('diamonds')
diamonds

#how many are 0.99 vs 1.00 carats? why?

#x,y,z - which are length, width, and depth
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
sns.countplot(diamonds['carat'])

# %%
sns.distplot(diamonds['carat'], kde=False, bins=np.arange(.2,2.05,.05).tolist())

# %%
sns.violinplot(x = diamonds['color'], y = diamonds['carat'])

# %%
sns.scatterplot(data = diamonds.query('y < 20 & x > 2.5'), x='x', y='y')
#.query() allows us to set conditions within the quotations

# %%
diamonds['price'].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
#explore price
#bins, first number is number of columns
#sns.distplot(diamonds['price'], kde= False, bins=5)
sns.distplot(diamonds.query('price > 1000 & price < 2000')['price'], kde = False, bins = 500)

# %%
sns.violinplot(x = diamonds['color'], y = diamonds.query('price < 10000 & price > 1000')['price'])

# %%
sns.jointplot(data=diamonds.query('carat<2 & price < 10000'), y = 'price',x='carat',kind='resid')
#sns.jointplot(data=diamonds.query('carat<2 & price < 10000'), y = 'price',x='carat',kind='reg')

# %%
#how is price related to cut?
sns.boxplot(data=diamonds.query('price < 6000'),x='cut',y='price')

# %% [markdown]
# # Stocks

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr # you might need to install this (see above)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# don't copy and paste these lists and number in several places 
# (which is what the original "simple program" did... that's bad programming!)
# instead, create a var - if we change it here, it changes everywhere
stocks = ['AAPL','MSFT','VZ']
start_yr = 2000

# load
stock_prices = pdr.get_data_yahoo(stocks, start=start_yr)
stock_prices = stock_prices.filter(like='Adj Close') # reduce to just columns with this in the name
stock_prices.columns = stocks # put their tickers as column names
stock_prices # print
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-e3661c65067b> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pandas_datareader as pdr # you might need to install this (see above)
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
stock_prices.stack().swaplevel.sort_index().reset_index()
stock_prices.columns = ['Firm', 'Date','Adj CLose']
stock_prices

# %%
# add return var.
# MAKE SURE YOU CREATE THE VARIABLES WITHIN EACH FIRM - use groupby
stock_prices['ret'] = stock_prices.groupby('Firm')['Adj Close'].pct_change()
stock_prices # print - the first ret for each firm should be missing...

# %%
stock_prices.groupby('Firm')['ret'].describe()

# %%
#q3 fig 1
#bad
#sns.distplot(stock_prices['ret'].dropna(), kde = False)
#better
sns.distplot(stock_prices.query('abs(ret)<.1')['ret'].dropna(), kde = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-22451b96ee6a> in <module>
#       3 #sns.distplot(stock_prices['ret'].dropna(), kde = False)
#       4 #better
# ----> 5 sns.distplot(stock_prices.query('abs(ret)<.1')['ret'].dropna(), kde = False)
#
# NameError: name 'stock_prices' is not defined

# %%
#q3 fig 2
sns.boxplot(x='ret',data=stocks_prices.query('abs(ret)ret<.1'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5981c5e4240b> in <module>
#       1 #q3 fig 2
# ----> 2 sns.boxplot(x='ret',data=stocks_prices.query('abs(ret)ret<.1'))
#
# NameError: name 'stocks_prices' is not defined

# %%
#q3 fig 3
sns.lineplot(data=stock_prices,x='Date',y='ret', hue='firm')
